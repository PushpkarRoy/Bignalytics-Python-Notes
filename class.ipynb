# %% [markdown]
#     Space sequene
#      memory storage
#     repl
#     what is pyhon
#     histort of pyhon
#     ad and dis ad of python

# %% [markdown]
# <h2 style="color:Red; font-weight:bold;"> Class Questins </h2>

# %% [markdown]
# Ques 1. Write a Python Program to print "Hello!"

# %%
welcome = "Hello!"
welcome
# Out:
# 'Hello!'

# %% [markdown]
# Quest 2. Write a python program to print the following string in speifice format samplen string:
#     "Twinkle, twinkle, lettle star, how I wonder what you are!
#     Up about the world so high. Like a diamond in the sky. Twinkle, twinkle, litter star, how I wonder what you are"
#
# Output in Poem line:
#
#     Twinkle, twinkle, lettle star,
#         how I wonder what you are!
#  	         Up about the world so high.
#   	        Like a diamond in the sky.
#     Twinkle, twinkle, litter star,
#     how I wonder what you are

# %%
print("Twinkle, twinkle, lettle star,\n how I wonder what you are!\n \t Up about the world so high.\n  \t Like a diamond in the sky.\n Twinkle, twinkle, litter star,\n how I wonder what you are")
# Out:
# Twinkle, twinkle, lettle star,
#  how I wonder what you are!
#  	 Up about the world so high.
#   	 Like a diamond in the sky.
#  Twinkle, twinkle, litter star,
#  how I wonder what you are

# %% [markdown]
# Ques 3. Write a python program that display your name, age, and address on three different lines.
#
#     Name: Monty
#     Age : 20
#     Address : Indore, M.P

# %%
name = input("Enter your name:- ")
age = int(input("What is your age:- "))
Address = input("Enter your address:- ")

print(f"Your name is{name}.\nYour age is {age}.\nAnd your addess is {Address}")
# Out:
# Your name isMonty.
# Your age is 20.
# And your addess is Indore, M.P

# %% [markdown]
# Quest 4. Write a python program to add Two number.

# %%
a = int(input("Enter first No.:- "))
b = int(input("Enter your second No:- "))

c = a + b
print(f"Your First no is:- {a}.\nYour second no is:- {b}.\nAnd Your Final total is {c}")
# Out:
# Your First no is:- 7888.
# Your second no is:- 1453.
# And Your Final total is 9341

# %% [markdown]
# Quest 5. Write a python program to Multiply Two Numbers.

# %%
a = int(input("Enter your first no:- "))
b = int(input("Enter your second no:- "))
c = a * b

print(f"Your first no is:- {a}\nYour second no is :- {b}\nAnd your final Result is :- {c}")
# Out:
# Your first no is:- 5
# Your second no is :- 6
# And your final Result is :- 30

# %% [markdown]
# Quest 6. Write a python program to Divide Two Number.

# %%
a = int(input("Enter your first no:- "))
b = int(input("Enter your second no:- "))
c = a / b

print(f"Your first no is:- {a}\nYour second no is :- {b}\nAnd your final Result is :- {c}")
# Out:
# Your first no is:- 10
# Your second no is :- 2
# And your final Result is :- 5.0

# %% [markdown]
# Quest 7. Write a python program to find the Area of a Trianglel. (area = 0.5, base * hight) Equilateral.

# %%
base = int(input("Enter your base value :- "))
hight = int(input("Enter your hight value :- "))


area = 0.5 * base * hight

print(f"Base of a Triangle is :- {base}.\nHight is :- {hight}.\nArea of a Triangle is :-{area}")
# Out:
# Base of a Triangle is :- 10.
# Hight is :- 5.
# Area of a Triangle is :-25.0

# %% [markdown]
# Quest 8. Write a python program to find the Area of a Reatangle. (area = length * width)

# %%
length = int(input("Enter the length of the rectangle:- "))
width = int(input("Enter the width of the rectangle:- "))

area = length * width

print(f"Length of the Rectangle is :- {length}.\nWidth of the Rectangle is :- {width}.\nArea of the Rectangle is :- {area}")
# Out:
# Length of the Rectangle is :- 12.
# Width of the Rectangle is :- 8.
# Area of the Rectangle is :- 96

# %% [markdown]
# Quest 9. Write a pthon program to find the area of a square.(area = side** 2)

# %%
side = int(input("Enter the value of side:- "))
area = side ** 2

print(f"Value of Square side is :- {side}.\nArea of a Square is :- {area}")
# Out:
# Value of Square side is :- 10.
# Area of a Square is :- 100

# %% [markdown]
# Quest 10. Write a python program to find area of a circle.(area = pi *(radus ** 2))

# %%
radius = int(input("Enter the value of Radius:- "))
pi = 3.14
area = pi *(radius ** 2)

print(f"We are conceder value of pi is :- {pi}.\nRadius is {radius}.\nArea of circle is  {area}")
# Out:
# We are conceder value of pi is :- 3.14.
# Radius is 7.
# Area of circle is  153.86

# %% [markdown]
# Quest 11. Write a python program to find the value of a sphere. (Volume = (4/3) * pi *(radius ** 3))

# %%
radius = int(input("Enter the value of Radius:- "))
pi = 3.14
volume = 4/3 * pi *(radius ** 3)
volume = round(volume,2)
print(f"We are conceder value of pi is :- {pi}. \nValue of Radius is :- {radius}.\nVolume of Sphere is:- {volume}")
# Out:
# We are conceder value of pi is :- 3.14.
# Value of Radius is :- 7.
# Volume of Sphere is:- 1436.03

# %% [markdown]
# Quest 12. Write a python program to find the volume of a Cylinder. (Volume = pi*(radius ** 2) * hight)

# %%
radius = int(input("Enter the value of Radius :- "))
hight = int(input("Hight of the Cylinder is :- "))
pi = 3.14
volume = pi*(radius **2) * hight

print(f"We are concedre value of pi is {pi}.\nRadius of the Cylinder is {radius}.\nHight of the Cylinder is {hight}.\nVolume of the Cylinder is {volume}")
# Out:
# We are concedre value of pi is 3.14.
# Radius of the Cylinder is 7.
# Hight of the Cylinder is 7.
#  Volume of the Cylinder is 1077.02

# %% [markdown]
# Quest 13. Write a python program to calculate the hypotenuse of a right angle triangle. (hypotenuse = (side1 ** 2 + side2 ** 2) ** 0.5)

# %%
side1 = int(input("First side of a Triangle is :- "))
side2 = int(input("Second side of a Triangle is :- "))

calcu = (side1 ** 2 + side2 ** 2) ** 0.5
calcu = round(calcu,2)

print(f"value of 1st side is :- {side1}.\nValue of 2nd side is :- {side2}. \nHypotenuse side of the right angle trianglie is :- {calcu}")
# Out:
# value of 1st side is :- 10.
# Value of 2nd side is :- 10.
# Hypotenuse side of the right angle trianglie is :- 14.14

# %% [markdown]
# Quest 14. Write a pyhon program to convert hight(in feet and inches) to centimetres and vice versa.

# %%
cm = int(input("Enter the hight :- "))

total_inch = cm / 2.54
total_inch = round(total_inch, 2)

total_feet = cm / 30.48
total_feet = round(total_feet,2)

print(f"hight in cm is :- {cm}\n Hight in inch is :- {total_inch}\n Hight in cm is :- {total_feet}")
# Out:
# hight in cm is :- 50
#  Hight in inch is :- 19.69
#  Hight in cm is :- 1.64

# %% [markdown]
# Quest 15. Write a program to convert the tempeature in celsius to Fahetnite and vice varsa.

# %%
celsius = int(input("Enter the celsius value:- "))

fahetnite = (celsius * 9/5) + 32

print(f"celsius value is :- {celsius}\nChange celsius into fahetnite is {fahetnite}")
# Out:
# celsius value is :- 36
# Change celsius into fahetnite is 96.8

# %% [markdown]
# Quest 16. Write a python program to convert Kilometer to meter, metre to centimetre, centimetre to millimetre and vice versa.

# %%
km = int(input("Enter the value:- "))

m = km * 1000
cm = m * 100
mm = cm * 10

print(f"km valu is {km}\nKm to m is :- {m}\nmeter to cm is :- {cm}\ncm to mm is :- {mm}")
# Out:
# km valu is 7
# Km to m is :- 7000
# meter to cm is :- 700000
# cm to mm is :- 7000000

# %% [markdown]
# Quest 17. Write a python program to convert all units of time (hour,minute,second) into second and vice versa.

# %%
hour = float(input("Enter the value :- "))

min = hour * 60
sec = min * 60 

print(f"Your hour is {hour}\nChange hour into min :- {min}\nChange min into sec :- {sec}")
# Out:
# Your hour is 2.5
# Change hour into min :- 150.0
# Change min into sec :- 9000.0

# %% [markdown]
# Quest 18. Write a python program to calculate the simple interest.

# %%
amount = int(input("Enter the amount or principle :- "))            #this is a principle 
rate = float(input("Enter the rate of interest :- "))               #Rate of interest 
time = int(input("Enter the no. of year :- "))                      #No of years 


si = (amount * rate * time) / 100
total_interest = si + amount

print(f"Your principle is :- {amount}\nYour interest rate is :- {rate}\nYour time peroid in year :- {time}\nYour Simple interest is {si}\nand your total value is {total_interest}")
# Out:
# Your principle is :- 100000
# Your interest rate is :- 6.0
# Your time peroid in year :- 2
# Your Simple interest is 12000.0
# and your total value is 112000.0

# %%
a = 10
b = 10/0
print(a)
print(b)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[4], line 2
#       1 a = 10
# ----> 2 b = 10/0
#       3 print(a)
#       4 print(b)
#
# ZeroDivisionError: division by zero
