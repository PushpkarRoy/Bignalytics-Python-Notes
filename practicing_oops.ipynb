# %% [markdown]
# del keyword

# %% [markdown]
# using a delete object proparties or object itself
#
#     dels1.name
#     del.s1

# %% [markdown]
# Private(like) attributes and methods

# %% [markdown]
# Inheritance
#
# Type of Inheritance

# %% [markdown]
# Super method ()

# %% [markdown]
# static method
#
# Class method
#
# instance method

# %% [markdown]
# Proparty decorator

# %% [markdown]
# polymorphism
